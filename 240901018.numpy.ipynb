# %%
import numpy as np
arr=np.array([[-1,2,0,4],[4,-0.5,6,0],[2.6,0,7,8],[3,7,5,6]])
print("Original array:\n",arr)
print("\nEvery other rows:\n",arr[0:3:2])
# Out:
# Original array:
#  [[-1.   2.   0.   4. ]
#  [ 4.  -0.5  6.   0. ]
#  [ 2.6  0.   7.   8. ]
#  [ 3.   7.   5.   6. ]]
#
# Every other rows:
#  [[-1.   2.   0.   4. ]
#  [ 2.6  0.   7.   8. ]]

# %%
import numpy as np
arr=np.array([[-1,2,0,4],[4,-0.5,6,0],[2.6,0,7,8],[3,7,5,6]])
print("\nOriginal array:",arr)
print("\nReturn every other element in the array:arr[:2];",arr[::2])
temp=arr[:2:3]
print("\nArray with first 2 rows and columns:\n",temp)
x= arr[[0,1,2,3],[3,2,1,0]]
print("\nElement at indices(0,3),(1,2),(2,1),""(3,0):\n",x)
# Out:
# Original array: [[-1.   2.   0.   4. ]
#  [ 4.  -0.5  6.   0. ]
#  [ 2.6  0.   7.   8. ]
#  [ 3.   7.   5.   6. ]]
#
# Return every other element in the array:arr[:2]; [[-1.   2.   0.   4. ]
#  [ 2.6  0.   7.   8. ]]
#
# Array with first 2 rows and columns:
#  [[-1.  2.  0.  4.]]
#
# Element at indices(0,3),(1,2),(2,1),(3,0):
#  [4. 6. 0. 3.]
